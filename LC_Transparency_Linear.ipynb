# %%
# coding: utf-8

# In[1]:


import numpy as np


# In[2]:


import scipy as sp


# In[4]:


import pandas as pd


# In[12]:


import matplotlib.pyplot as plt
import seaborn as sns

#数据写入部分

# In[17]:


training_df = pd.read_excel("C:/Users/chenyuxiang/Desktop/Regression_Data.xlsx", sheet_name='Sheet1', header=0)


# In[35]:

#feature_cols = ['T01','T02','T03']
feature_cols = ['T0101','T0102','T0201','T0202','T0203','T0204','T0205','T0206','T0207','T0208','T0209','T0210','T0211','T0212','T0213',
'T0301','T0302','T0303','T0304','T0305','T0306','T0307','T0308','T0309']


# In[36]:


x = training_df[feature_cols]
y = training_df['SCORE']


# In[37]:


from sklearn.cross_validation import train_test_split  #引用交叉验证  
x_train,x_test, y_train, y_test = train_test_split(x, y, random_state=1)  


# In[38]:


from sklearn.linear_model import LinearRegression  
linreg = LinearRegression()  
model = linreg.fit(x_train, y_train)  
print('Model:',model)  
print('Intercept:', linreg.intercept_)


# In[40]:


coef_zipped = zip(feature_cols, linreg.coef_)
print('Coefficients:',list(coef_zipped))






#检验部分

# In[43]:


y_pred = linreg.predict(x_test)  
print('Prediction', y_pred)  


# In[44]:


print('Test_Data:', y_test)



# In[48]:


#均方根误差(Root Mean Squared Error, RMSE)
from sklearn import metrics  

sum_mean=0  
for i in range(len(y_pred)):  
    sum_mean += (y_pred[i]-y_test.values[i])**2  
sum_error=np.sqrt(sum_mean/len(y_pred))
print('Root Mean Squared Error:', sum_error)


# In[51]:


#ROC曲线
import matplotlib.pyplot as plt  
plt.figure()  
plt.plot(range(len(y_pred)),y_pred,'b',label="predict")  
plt.plot(range(len(y_pred)),y_test,'r',label="test")  
plt.legend(loc="upper right")
plt.xlabel("Companies")  
plt.ylabel("Transparency Index")
# Out:
# Model: LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Intercept: 0.2875000644732099
# Coefficients: [('T0101', 0.0), ('T0102', 0.11538463267503245), ('T0201', 0.016346154893022734), ('T0202', 0.023076879897715306), ('T0203', 0.011538458856230695), ('T0204', 5.551115123125783e-17), ('T0205', 0.01923077047036864), ('T0206', 0.019230770468387077), ('T0207', 1.5612511283791264e-17), ('T0208', -4.85722573273506e-17), ('T0209', 0.019230769551047702), ('T0210', 1.3877787807814457e-17), ('T0211', -1.3877787807814457e-17), ('T0212', 0.019230769321602566), ('T0213', 0.019230771287299695), ('T0301', 0.012587415822906633), ('T0302', 0.08181817348444412), ('T0303', 0.04405594086262308), ('T0304', 1.915837744194086e-46), ('T0305', 0.017307694701549158), ('T0306', 0.017307689424548165), ('T0307', 8.758115402030107e-47), ('T0308', 0.017307693105943437), ('T0309', 0.22499999363371984)]
# Prediction [0.76625875 0.74702798 0.78933568 0.77290211 0.74702798 0.82587414
#  0.76048952 0.77779722 0.78356645 0.73444057 0.78356645 0.78356645
#  0.77875875 0.76625875 0.78548952 0.78068183 0.76433568 0.76625875
#  0.78356644 0.77972029 0.75996505 0.78548952 0.77587414 0.77395107
#  0.78356645 0.76433568 0.74702798 0.79178323 0.76905596 0.76625875
